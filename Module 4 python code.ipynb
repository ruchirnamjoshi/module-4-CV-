# %% [markdown]
# #  Code for module 4 question 1

# %%
import cv2
import numpy as np
import pytesseract
import depthai as dai

# Camera matrix and distortion coefficients
camera_mtx = np.load('camera_mtx.npy')  # Replace with your actual file path
dist_coeffs = np.load('dist_coeffs.npy')  # Replace with your actual file path


pytesseract.pytesseract.tesseract_cmd = '/opt/homebrew/bin/tesseract'



def preprocess_for_contours(frame):
    gray = frame
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    edged = cv2.Canny(blurred, 75, 200)
    return edged

def find_breeze_card(frame, original):
    config = '--oem 3 --psm 11'
    details = pytesseract.image_to_data(frame, config=config, output_type=pytesseract.Output.DICT)
    
    for i in range(len(details['level'])):
        if int(details['conf'][i]) > 60:
            text = details['text'][i].lower()
            if 'breez' or 'marta' in text:
                text_x, text_y, text_w, text_h = int(details['left'][i]), int(details['top'][i]), int(details['width'][i]), int(details['height'][i])

                # Preprocess image for contour detection
                edged = preprocess_for_contours(original)
                contours, _ = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                # Find the smallest contour that is larger than the text but still contains the entire text
                best_contour = None
                min_area_diff = float('inf')

                for cnt in contours:
                    x, y, w, h = cv2.boundingRect(cnt)
                    # Check if the contour encloses the text
                    if x <= text_x and x + w >= text_x + text_w and y <= text_y and y + h >= text_y + text_h:
                        area_cnt = w * h
                        area_text = text_w * text_h
                        area_diff = area_cnt - area_text

                        if area_diff > 0 and area_diff < min_area_diff:
                            min_area_diff = area_diff
                            best_contour = (x, y, w, h)

                if best_contour:
                    return best_contour

    return None




def calculate_dimensions_in_mm(box, depth_frame):
    #Calculate dimensions of the card using depth data.
    x, y, w, h = box
    depth_roi = depth_frame[y:y+h, x:x+w]
    depth = np.median(depth_roi[depth_roi > 0])  # Avoid zero depth
    
    # Convert pixels to millimeters using the camera matrix
    # We need to solve for real-world coordinates where z (depth) is known
    # and we find the corresponding x and y in real-world units.
    focal_length_px = (camera_mtx[0, 0] + camera_mtx[1, 1]) / 2
    cx, cy = camera_mtx[0, 2], camera_mtx[1, 2]

    x_mm = (x - cx) * depth / focal_length_px
    y_mm = (y - cy) * depth / focal_length_px
    w_mm = w * depth / focal_length_px
    h_mm = h * depth / focal_length_px
    
    return w_mm, h_mm, depth

def create_pipeline():
    pipeline = dai.Pipeline()

    # Create mono cameras
    cam_left = pipeline.create(dai.node.MonoCamera)
    cam_right = pipeline.create(dai.node.MonoCamera)
    # Set camera properties, omitted for brevity

    # Create stereo depth node
    stereo = pipeline.create(dai.node.StereoDepth)
    # Set stereo properties, omitted for brevity

    # Link cameras to stereo depth
    cam_left.out.link(stereo.left)
    cam_right.out.link(stereo.right)

    # Create XLinkOut for grayscale image from left camera
    xout_left = pipeline.create(dai.node.XLinkOut)
    xout_left.setStreamName("left")
    cam_left.out.link(xout_left.input)  # Assuming we are using left camera for grayscale output

    # Create XLinkOut for depth output
    xout_depth = pipeline.create(dai.node.XLinkOut)
    xout_depth.setStreamName("depth")
    stereo.depth.link(xout_depth.input)

    return pipeline

def main():
    pipeline = create_pipeline()
    with dai.Device(pipeline) as device:
        q_gray = device.getOutputQueue(name="left", maxSize=8, blocking=False)
        q_depth = device.getOutputQueue(name="depth", maxSize=8, blocking=False)

        tracker = None
        card_detected = False
        while True:
            in_gray = q_gray.get()  # Get the grayscale frame
            in_depth = q_depth.get()  # Get the depth frame

            gray_frame = in_gray.getCvFrame()
            depth_frame = in_depth.getFrame()

            if not card_detected:
                card_bbox = find_breeze_card(gray_frame,gray_frame)
                if card_bbox:
                    x, y, w, h = card_bbox
                    tracker = cv2.TrackerCSRT_create()
                    tracker.init(gray_frame, (x, y, w, h))
                    card_detected = True
                    print("Card detected and tracking started.")
                else:
                    print("No card detected")
            
            if card_detected:
                success, box = tracker.update(gray_frame)
                if success:
                    x, y, w, h = map(int, box)
                    cv2.rectangle(gray_frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
                    dimensions_mm = calculate_dimensions_in_mm((x, y, w, h), depth_frame)
                    print(f"Tracked Card dimensions: Width={dimensions_mm[0]:.2f} mm, Height={dimensions_mm[1]:.2f} mm, Depth={dimensions_mm[2]:.2f} mm")

            cv2.imshow("Breeze Card Detection", gray_frame)
            if cv2.waitKey(1) == ord('q'):
                break

        cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# [194430102154F31200] [1.1] [0.862] [MonoCamera(0)] [error] OV7251 only supports THE_480_P/THE_400_P resolutions, defaulting to THE_480_P
# [194430102154F31200] [1.1] [0.863] [MonoCamera(1)] [error] OV7251 only supports THE_480_P/THE_400_P resolutions, defaulting to THE_480_P
# No card detected
# No card detected
# No card detected
# Card detected and tracking started.
# Tracked Card dimensions: Width=246.29 mm, Height=350.49 mm, Depth=2410.00 mm
# Tracked Card dimensions: Width=238.68 mm, Height=340.34 mm, Depth=2249.00 mm
# Tracked Card dimensions: Width=287.38 mm, Height=408.96 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=596.86 mm, Height=851.07 mm, Depth=5624.00 mm
# Tracked Card dimensions: Width=292.90 mm, Height=417.25 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=319.46 mm, Height=455.08 mm, Depth=3067.00 mm
# Tracked Card dimensions: Width=298.43 mm, Height=425.54 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=275.40 mm, Height=392.70 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=248.62 mm, Height=353.60 mm, Depth=2249.00 mm
# Tracked Card dimensions: Width=270.30 mm, Height=385.05 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=219.68 mm, Height=312.94 mm, Depth=2109.00 mm
# Tracked Card dimensions: Width=223.82 mm, Height=319.15 mm, Depth=2109.00 mm
# Tracked Card dimensions: Width=192.84 mm, Height=274.00 mm, Depth=1776.00 mm
# Tracked Card dimensions: Width=255.77 mm, Height=364.70 mm, Depth=2410.00 mm
# Tracked Card dimensions: Width=203.59 mm, Height=289.27 mm, Depth=1875.00 mm
# Tracked Card dimensions: Width=198.99 mm, Height=283.74 mm, Depth=1875.00 mm
# Tracked Card dimensions: Width=166.57 mm, Height=236.66 mm, Depth=1534.00 mm
# Tracked Card dimensions: Width=174.49 mm, Height=247.92 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=152.67 mm, Height=216.91 mm, Depth=1406.00 mm
# Tracked Card dimensions: Width=261.69 mm, Height=371.81 mm, Depth=2410.00 mm
# Tracked Card dimensions: Width=281.77 mm, Height=400.35 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=275.40 mm, Height=392.70 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=397.87 mm, Height=567.33 mm, Depth=3749.00 mm
# Tracked Card dimensions: Width=305.34 mm, Height=433.83 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=275.40 mm, Height=392.70 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=298.43 mm, Height=425.54 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=298.43 mm, Height=425.54 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=397.87 mm, Height=567.33 mm, Depth=3749.00 mm
# Tracked Card dimensions: Width=281.77 mm, Height=400.35 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=281.77 mm, Height=400.35 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=298.43 mm, Height=425.54 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=292.90 mm, Height=417.25 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=292.90 mm, Height=417.25 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=270.30 mm, Height=385.05 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=270.30 mm, Height=385.05 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=251.03 mm, Height=357.60 mm, Depth=2410.00 mm
# Tracked Card dimensions: Width=292.90 mm, Height=417.25 mm, Depth=2812.00 mm
# Tracked Card dimensions: Width=246.29 mm, Height=350.49 mm, Depth=2410.00 mm
# Tracked Card dimensions: Width=206.76 mm, Height=294.54 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=270.30 mm, Height=385.05 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=229.84 mm, Height=327.08 mm, Depth=2249.00 mm
# Tracked Card dimensions: Width=155.69 mm, Height=222.00 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=275.40 mm, Height=392.70 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=281.77 mm, Height=400.35 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=286.87 mm, Height=408.00 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=275.40 mm, Height=392.70 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=233.15 mm, Height=331.59 mm, Depth=2109.00 mm
# Tracked Card dimensions: Width=325.49 mm, Height=464.13 mm, Depth=3067.00 mm
# Tracked Card dimensions: Width=238.68 mm, Height=340.34 mm, Depth=2249.00 mm
# Tracked Card dimensions: Width=281.77 mm, Height=400.35 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=219.44 mm, Height=312.09 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=281.77 mm, Height=400.35 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=261.69 mm, Height=371.81 mm, Depth=2410.00 mm
# Tracked Card dimensions: Width=203.59 mm, Height=289.27 mm, Depth=1875.00 mm
# Tracked Card dimensions: Width=261.69 mm, Height=371.81 mm, Depth=2410.00 mm
# Tracked Card dimensions: Width=281.77 mm, Height=400.35 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=183.18 mm, Height=260.27 mm, Depth=1687.00 mm
# Tracked Card dimensions: Width=215.54 mm, Height=306.24 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=234.26 mm, Height=333.71 mm, Depth=2249.00 mm
# Tracked Card dimensions: Width=159.78 mm, Height=227.62 mm, Depth=1534.00 mm
# Tracked Card dimensions: Width=198.99 mm, Height=283.74 mm, Depth=1875.00 mm
# Tracked Card dimensions: Width=188.48 mm, Height=268.76 mm, Depth=1776.00 mm
# Tracked Card dimensions: Width=215.53 mm, Height=306.72 mm, Depth=2109.00 mm
# Tracked Card dimensions: Width=181.50 mm, Height=258.29 mm, Depth=1776.00 mm
# Tracked Card dimensions: Width
mm, Depth=1250.00 mm
# Tracked Card dimensions: Width=92.07 mm, Height=130.75 mm, Depth=937.00 mm
# Tracked Card dimensions: Width=141.27 mm, Height=201.10 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=92.83 mm, Height=132.15 mm, Depth=964.00 mm
# Tracked Card dimensions: Width=90.23 mm, Height=128.44 mm, Depth=937.00 mm
# Tracked Card dimensions: Width=93.58 mm, Height=133.06 mm, Depth=992.00 mm
# Tracked Card dimensions: Width=65.00 mm, Height=92.42 mm, Depth=689.00 mm
# Tracked Card dimensions: Width=83.77 mm, Height=119.11 mm, Depth=888.00 mm
# Tracked Card dimensions: Width=148.44 mm, Height=211.60 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=148.44 mm, Height=211.60 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=135.51 mm, Height=193.17 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=135.51 mm, Height=193.17 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=119.90 mm, Height=170.92 mm, Depth=1298.00 mm
# Tracked Card dimensions: Width=129.87 mm, Height=185.14 mm, Depth=1406.00 mm
# Tracked Card dimensions: Width=129.87 mm, Height=185.14 mm, Depth=1406.00 mm
# Tracked Card dimensions: Width=135.51 mm, Height=193.17 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=135.51 mm, Height=193.17 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=132.64 mm, Height=188.59 mm, Depth=1406.00 mm
# Tracked Card dimensions: Width=138.39 mm, Height=196.77 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=132.64 mm, Height=188.59 mm, Depth=1406.00 mm
# Tracked Card dimensions: Width=124.70 mm, Height=177.76 mm, Depth=1350.00 mm
# Tracked Card dimensions: Width=124.70 mm, Height=177.76 mm, Depth=1350.00 mm
# Tracked Card dimensions: Width=113.67 mm, Height=161.63 mm, Depth=1205.00 mm
# Tracked Card dimensions: Width=138.39 mm, Height=196.77 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=132.64 mm, Height=188.59 mm, Depth=1406.00 mm
# Tracked Card dimensions: Width=122.45 mm, Height=174.10 mm, Depth=1298.00 mm
# Tracked Card dimensions: Width=176.88 mm, Height=251.50 mm, Depth=1875.00 mm
# Tracked Card dimensions: Width=117.92 mm, Height=167.67 mm, Depth=1250.00 mm
# Tracked Card dimensions: Width=112.00 mm, Height=159.42 mm, Depth=1163.00 mm
# Tracked Card dimensions: Width=102.64 mm, Height=145.94 mm, Depth=1088.00 mm
# Tracked Card dimensions: Width=132.64 mm, Height=188.59 mm, Depth=1406.00 mm
# Tracked Card dimensions: Width=289.33 mm, Height=411.38 mm, Depth=3067.00 mm
# Tracked Card dimensions: Width=318.29 mm, Height=452.56 mm, Depth=3374.00 mm
# Tracked Card dimensions: Width=324.92 mm, Height=462.51 mm, Depth=3374.00 mm
# Tracked Card dimensions: Width=249.90 mm, Height=355.72 mm, Depth=2595.00 mm
# Tracked Card dimensions: Width=195.06 mm, Height=276.98 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=331.55 mm, Height=470.80 mm, Depth=3374.00 mm
# Tracked Card dimensions: Width=114.28 mm, Height=162.28 mm, Depth=1163.00 mm
# Tracked Card dimensions: Width=236.82 mm, Height=336.28 mm, Depth=2410.00 mm
# Tracked Card dimensions: Width=207.24 mm, Height=294.28 mm, Depth=2109.00 mm
# Tracked Card dimensions: Width=207.24 mm, Height=294.28 mm, Depth=2109.00 mm
# Tracked Card dimensions: Width=324.92 mm, Height=462.51 mm, Depth=3374.00 mm
# Tracked Card dimensions: Width=221.00 mm, Height=313.82 mm, Depth=2249.00 mm
# Tracked Card dimensions: Width=161.07 mm, Height=228.97 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=147.04 mm, Height=209.03 mm, Depth=1467.00 mm
# Tracked Card dimensions: Width=161.07 mm, Height=228.97 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=153.75 mm, Height=218.57 mm, Depth=1534.00 mm
# Tracked Card dimensions: Width=198.96 mm, Height=282.83 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=211.39 mm, Height=300.50 mm, Depth=2109.00 mm
# Tracked Card dimensions: Width=153.75 mm, Height=218.57 mm, Depth=1534.00 mm
# Tracked Card dimensions: Width=169.09 mm, Height=240.37 mm, Depth=1687.00 mm
# Tracked Card dimensions: Width=198.96 mm, Height=282.83 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=174.52 mm, Height=247.82 mm, Depth=1776.00 mm
# Tracked Card dimensions: Width=187.93 mm, Height=267.16 mm, Depth=1875.00 mm
# Tracked Card dimensions: Width=195.06 mm, Height=276.98 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=169.09 mm, Height=240.37 mm, Depth=1687.00 mm
# Tracked Card dimensions: Width=195.06 mm, Height=276.98 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=195.06 mm, Height=276.98 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=165.77 mm, Height=235.40 mm, Depth=1687.00 mm
# Tracked Card dimensions: Width=198.96 mm, Height=282.83 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=150.74 mm, Height=214.05 mm, Depth=1534.00 mm
# Tracked Card dimensions: Width=157.91 mm, Height=224.24 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=195.06 mm, Height=276.98 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=165.77 mm, Height=235.40 mm, Depth=1687.00 mm
# Tracked Card dimensions: Width=153.75 mm, Height=218.57 mm, Depth=1534.00 mm
# Tracked Card dimensions: Width=157.91 mm, Height=224.24 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=198.96 mm, Height=282.83 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=165.77 mm, Height=235.40 mm, Depth=1687.00 mm
# Tracked Card dimensions: Width=150.74 mm, Height=214.05 mm, Depth=1534.00 mm
# Tracked Card dimensions: Width=195.06 mm, Height=276.98 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=198.96 mm, Height=282.83 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=195.06 mm, Height=276.98 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=157.91 mm, Height=224.24 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=157.91 mm, Height=224.24 mm, Depth=1607.00 mm
# Tracked Card dimensions: Width=198.96 mm, Height=282.83 mm, Depth=1985.00 mm
# Tracked Card dimensions: Width=184.25 mm, Height=261.63 mm, Depth=1875.00 mm

# %% [markdown]
# Note - While testing different objects of different dimensions from different depths were tested.
